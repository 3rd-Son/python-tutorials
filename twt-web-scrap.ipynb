# %% [markdown]
# ### ***GPU PRICE SCRAPING***

# %%
import requests
from bs4 import BeautifulSoup as bs

# %%
url = 'https://www.newegg.ca/gigabyte-geforce-rtx-4090-gv-n4090gaming-oc-24gd/p/N82E16814932550'
results = requests.get(url)
print(results)
# Out:
# <Response [200]>

# %% [markdown]
# ##### *We can now make it better by using beautifulsouop*

# %%
doc = bs(results.text, 'html.parser')
print(doc.prettify())
# Out:
# <!DOCTYPE html>
# <html class="show-tab-store" lang="en-ca">
#  <head>
#   <title>
#    GIGABYTE Gaming GeForce RTX 4090 Graphics Card PCIe 4.0 24GB - Newegg.ca
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta content="always" name="referrer"/>
#   <meta content="Newegg, Newegg.ca, GIGABYTE Gaming GeForce RTX 4090 24GB GDDR6X PCI Express 4.0 x16 ATX Video Card GV-N4090GAMING OC-24GD" name="keywords"/>
#   <meta content="Buy the RTX 40 series 3rd generation architecture GPU, GIGABYTE Gaming GeForce RTX 4090 Graphics Card PCIe 4.0 384-Bit GDDR6X 24GB at Newegg" name="description"/>
#   <meta content="https://c1.neweggimages.com/ProductImage/14-932-550-23.jpg" property="og:image"/>
#   <meta content="Buy GIGABYTE Gaming GeForce RTX 4090 24GB GDDR6X PCI Express 4.0 x16 ATX Video Card GV-N4090GAMING OC-24GD with fast shipping and top-rated customer service. Once you know, you Newegg!" property="og:description"/>
# ...

# %% [markdown]
# ##### *Now we want to find the price of the gpu in this link*

# %%
# we just have to search for the dollar symbol itself
price = doc.find_all(text='$')
price
# Out:
# ['$', '$', '$', '$']

# %% [markdown]
# ##### *Now we will find tha parent of the dollar symbol so we can get the tag of the dollar symbol and price attached to the dollar symbol*

# %%
parent = price[0].parent
parent
# Out:
# <li class="price-current"><span class="price-current-label"></span>$<strong>2,299</strong><sup>.99</sup></li>

# %%
actual_price = parent.find('strong').string
actual_price
# Out:
# '2,299'
